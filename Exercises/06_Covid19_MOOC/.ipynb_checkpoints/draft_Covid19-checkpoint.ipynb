# %%
import numpy as np
import os
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"time_series_covid19_confirmed_global.csv")
df.tail()
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  \
# 284        0        0        0        0        0  ...   703228  703228
# 285        0        0        0        0        0  ...      535     535
# 286        0        0        0        0        0  ...    11945   11945
# 287        0        0        0        0        0  ...   343012  343012
# 288        0        0        0        0        0  ...   263921  264127
#
#      3/2/23  3/3/23  3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 284  703228  703228  703228  703228  703228  703228  703228  703228
# 285     535     535     535     535     535     535     535     535
# 286   11945   11945   11945   11945   11945   11945   11945   11945
# 287  343079  343079  343079  343135  343135  343135  343135  343135
# 288  264127  264127  264127  264127  264127  264127  264276  264276
#
# [5 rows x 1147 columns]

# %% [markdown]
# ## Data wrangling

# %%
df3 = df.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'])

df3.tail()
# Out:
#        Province/State        Country/Region        Lat        Long variable  \
# 330322            NaN    West Bank and Gaza  31.952200   35.233200   3/9/23
# 330323            NaN  Winter Olympics 2022  39.904200  116.407400   3/9/23
# 330324            NaN                 Yemen  15.552727   48.516388   3/9/23
# 330325            NaN                Zambia -13.133897   27.849332   3/9/23
# 330326            NaN              Zimbabwe -19.015438   29.154857   3/9/23
#
#          value
# 330322  703228
# 330323     535
# 330324   11945
# 330325  343135
# 330326  264276

# %%
df4 = df3.rename(columns={"variable": "Date", "value": "Cases", "Province/State": "State", "Country/Region": "Country" })

df4.tail()
# Out:
#        State               Country        Lat        Long    Date   Cases
# 330322   NaN    West Bank and Gaza  31.952200   35.233200  3/9/23  703228
# 330323   NaN  Winter Olympics 2022  39.904200  116.407400  3/9/23     535
# 330324   NaN                 Yemen  15.552727   48.516388  3/9/23   11945
# 330325   NaN                Zambia -13.133897   27.849332  3/9/23  343135
# 330326   NaN              Zimbabwe -19.015438   29.154857  3/9/23  264276

# %% [markdown]
# ## Plot

# %% [markdown]
# Make a graph showing the evolution of the cumulative number of cases over time for: Belgium, China (all provinces except Hong Kong), China, Hong-Kong, France except Dom/Tom, Germany, Iran, Italy, Japan, Korea South, Netherlands without the colonies, Portugal, Spain, United Kingdom without the colonies, US.
#
#
# Next, make a graph with the date on the x-axis and the cumulative number of cases at this date on the y-axis

# %%
sel_countries = df4.query('Country == "Belgium" or Country == "Germany" or Country == "Iran" or Country == "Italy" or Country == "Japan" or Country == "Korea South" or Country == "Spain" or Country == "Portugal" or Country == "US"')

sel_countries.head(30)
# Out:
#      State   Country        Lat        Long     Date  Cases
# 24     NaN   Belgium  50.833300    4.469936  1/22/20      0
# 135    NaN   Germany  51.165691   10.451526  1/22/20      0
# 150    NaN      Iran  32.427908   53.688046  1/22/20      0
# 154    NaN     Italy  41.871940   12.567380  1/22/20      0
# 156    NaN     Japan  36.204824  138.252924  1/22/20      2
# 330238   NaN  Netherlands  52.1326  5.2913  3/9/23  8599981

# %%
uk = df4.query('Country == "United Kingdom"')

uk_nocol = uk.query('Lat == 55.378100')

uk_nocol.head()

len(uk_nocol)
# Out:
# 1143

# %%
#frames = [sel_countries, hongkong, france_nocol, uk_nocol, nl_nocol]

#result = pd.concat(frames, ignore_index=True)

result.tail(100)
# Out:
#       State         Country        Lat        Long    Date     Cases
# 1838    NaN           Spain  40.463667   -3.749220  9/7/20    525549
# 1839    NaN              US  40.000000 -100.000000  9/7/20   6319464
# 9373    NaN       Hong Kong  22.300000  114.200000  9/7/20      4889
# 11659   NaN  United Kingdom  55.378100   -3.436000  9/7/20    350100
# 10881   NaN          France  46.227600    2.213700  9/7/21   6702711
# ...     ...             ...        ...         ...     ...       ...
# 7692    NaN           Japan  36.204824  138.252924  9/9/22  19999466
# 7690    NaN            Iran  32.427908   53.688046  9/9/22   7537781
# 7689    NaN         Germany  51.165691   10.451526  9/9/22  32422084
# 11248   NaN          France  46.227600    2.213700  9/9/22  33718369
# 7691    NaN           Italy  41.871940   12.567380  9/9/22  22020154
#
# [100 rows x 6 columns]

# %%
#result.query('Country == "Hong Kong"')
# Out:
#       State    Country   Lat   Long     Date    Cases
# 9489    NaN  Hong Kong  22.3  114.2   1/1/21     8888
# 9854    NaN  Hong Kong  22.3  114.2   1/1/22    12667
# 10219   NaN  Hong Kong  22.3  114.2   1/1/23  2648994
# 9498    NaN  Hong Kong  22.3  114.2  1/10/21     9242
# 9863    NaN  Hong Kong  22.3  114.2  1/10/22    12959
# ...     ...        ...   ...    ...      ...      ...
# 9739    NaN  Hong Kong  22.3  114.2   9/8/21    12131
# 10104   NaN  Hong Kong  22.3  114.2   9/8/22  1623078
# 9375    NaN  Hong Kong  22.3  114.2   9/9/20     4901
# 9740    NaN  Hong Kong  22.3  114.2   9/9/21    12133
# 10105   NaN  Hong Kong  22.3  114.2   9/9/22  1633154
#
# [1143 rows x 6 columns]

# %%
result = result.sort_values(by=['Date'])

# %%
## NOT WORKING


fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(46,45)) #, sharey=True


sns.lineplot(data = result, 
              x= "Date", 
              y="Cases", 
              hue="Country"
             ) 

ax.set_xticks(range(8))

# %%
# WORKS


fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(46,45)) #, sharey=True


sns.lineplot(data = sel_countries, 
              x= "Date", 
              y="Cases", 
              hue="Country"
             ) 


sns.lineplot(data = nl_nocol, 
              x= "Date", 
              y="Cases", 
             label = "Nether"
             ) 

sns.lineplot(data = france_nocol, 
              x= "Date", 
              y="Cases", 
             label = "France"
             ) 
sns.lineplot(data = uk_nocol, 
              x= "Date", 
              y="Cases", 
             label = "UK"
             ) 
sns.lineplot(data =  hongkong, 
              x= "Date", 
              y="Cases", 
             label = "Hong Kong"
             ) 


ax.set_xticks(range(0, 1143, 250))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-158-9eb76237c3e6> in <module>
#       8               x= "Date",
#       9               y="Cases",
# ---> 10               hue="Country"
#      11              )
#      12
#
# ~\miniconda3\envs\ml\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\miniconda3\envs\ml\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     701     p._attach(ax)
#     702
# --> 703     p.plot(ax, kwargs)
#     704     return ax
#     705
#
# ~\miniconda3\envs\ml\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     555
#     556         # Finalize the axes details
# --> 557         self._add_axis_labels(ax)
#     558         if self.legend:
#     559             self.add_legend_data(ax)
#
# ~\miniconda3\envs\ml\lib\site-packages\seaborn\_core.py in _add_axis_labels(self, ax, default_x, default_y)
#    1185         # when the axes are not shared. Maybe that makes sense?
#    1186         if not ax.get_xlabel():
# -> 1187             x_visible = any(t.get_visible() for t in ax.get_xticklabels())
#    1188             ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1189         if not ax.get_ylabel():
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1253         if minor:
#    1254             return self.get_minorticklabels()
# -> 1255         return self.get_majorticklabels()
#    1256
#    1257     def get_majorticklines(self):
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1205     def get_majorticklabels(self):
#    1206         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1207         ticks = self.get_major_ticks()
#    1208         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1209         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1380         while len(self.majorTicks) < numticks:
#    1381             # Update the new tick label properties from the old.
# -> 1382             tick = self._get_tick(major=True)
#    1383             self.majorTicks.append(tick)
#    1384             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2014         else:
#    2015             tick_kw = self._minor_tick_kw
# -> 2016         return XTick(self.axes, 0, major=major, **tick_kw)
#    2017
#    2018     def set_label_position(self, position):
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     415
#     416     def __init__(self, *args, **kwargs):
# --> 417         super().__init__(*args, **kwargs)
#     418         # x in data coords, y in axes coords
#     419         self.tick1line.set(
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     164         )
#     165         self.gridline.get_path()._interpolation_steps = \
# --> 166             GRIDLINE_INTERPOLATION_STEPS
#     167         self.label1 = mtext.Text(
#     168             np.nan, np.nan,
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1009         """
#    1010         if self._invalidy or self._invalidx:
# -> 1011             self.recache()
#    1012         return self._path
#    1013
#
# ~\miniconda3\envs\ml\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     660             y = self._y
#     661
# --> 662         self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     663         self._x, self._y = self._xy.T  # views
#     664
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(56,25)) #, sharey=True


sns.lineplot(data = sel_countries, 
              x= "Date", 
              y="Cases", 
              hue="Country"
             ) 


sns.lineplot(data = nl_nocol, 
              x= "Date", 
              y="Cases", 
             label = "Nether"
             ) 

sns.lineplot(data = france_nocol, 
              x= "Date", 
              y="Cases", 
             label = "France"
             ) 
sns.lineplot(data = uk_nocol, 
              x= "Date", 
              y="Cases", 
             label = "UK"
             ) 
sns.lineplot(data =  hongkong, 
              x= "Date", 
              y="Cases", 
             label = "Hong Kong"
             ) 


ax.set_xticks(range(0, 1143, 250)) 

plt.yscale('log')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(56,25)) #, sharey=True

sns.lineplot(data = df5, 
              x= "Date", 
              y="Cases", 
              hue="Country"
             )
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Cases'>

# %%
## TRY again to have 1 dataframe
# TODO: fix hongkong, add china

df42 = df4.assign(Country = 'Hong Kong')

#df42.query('State == "Hong Kong"') # check


# make one df
#df5 = df4.query('Lat == 46.227600 or Lat == 52.1326 or Lat == 55.378100 or Country == "Belgium" or Country == "Germany" or Country == "Iran" or Country == "Italy" or Country == "Japan" or Country == "Korea South" or Country == "Spain" or Country == "Portugal" or Country == "US" ')
# Out:
#             State    Country   Lat   Long     Date    Cases
# 71      Hong Kong  Hong Kong  22.3  114.2  1/22/20        0
# 360     Hong Kong  Hong Kong  22.3  114.2  1/23/20        2
# 649     Hong Kong  Hong Kong  22.3  114.2  1/24/20        2
# 938     Hong Kong  Hong Kong  22.3  114.2  1/25/20        5
# 1227    Hong Kong  Hong Kong  22.3  114.2  1/26/20        8
# ...           ...        ...   ...    ...      ...      ...
# 328953  Hong Kong  Hong Kong  22.3  114.2   3/5/23  2876106
# 329242  Hong Kong  Hong Kong  22.3  114.2   3/6/23  2876106
# 329531  Hong Kong  Hong Kong  22.3  114.2   3/7/23  2876106
# 329820  Hong Kong  Hong Kong  22.3  114.2   3/8/23  2876106
# 330109  Hong Kong  Hong Kong  22.3  114.2   3/9/23  2876106
#
# [1143 rows x 6 columns]
